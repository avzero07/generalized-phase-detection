# %% [markdown]
# ## Load EST_LIB

# %%
import os

# %%
from tqdm.notebook import tqdm

# %%
from est_lib.util.obspy_util import *
from est_lib.util.obspy_plot import *

# %% [markdown]
# # Specify Meta Parameters

# %%
file_preamble = "event"
stream_types = ['vel','acc']
channels = {'vel':['HHN','HHE','HHZ'],'acc':['HNN','HNE','HNZ']}
op_dir = os.path.join('..','data')

sta_list = {
    'BFSB','CBB','CLRS','HOLB','HOPB','LLLB','NLLB','NTKA','PACB','PHC','PTRF','SNB','SYMB','VGZ','WOSB'
}

# %%
choice = stream_types[0]

# %% [markdown]
# ## Retrieve Station Metadata

# %%
station_metadata = inventory_retriever(sta_list=sta_list)

# %% [markdown]
# # Event Spec

# %%
time = '2019-12-23T20:56:23.555000Z'
mag = '6'
event_folder_name = 'event_{}_{}_{}'.format(mag,time.replace(':','_').replace('.','_'),choice)
event_folder_path = os.path.join(op_dir,event_folder_name)

# Create Event Folder if it doesn't Exist
try:
    os.mkdir(event_folder_path)
except FileExistsError:
    print("Folder Already Exists, Moving On!")

# %% [markdown]
# ## Retrieve Waveform Data

# %%
#data = stream_reader('264_HOLB-velocity.mseed')

data = stream_retriever(event_time=time,time_format='string',
                     seconds_before=600,
                     seconds_after=1500,
                     network='CN',
                     sta_list=sta_list,
                     channel_list=channels[choice],
                     client_obj=client)

# %% [markdown]
# ## Visualize EQ Source and Stations

# %%
lat = 50.178
lon = -129.816
op = ray_plot(
    ev_lat=lat,
    ev_lon=lon,
    streams=data,
    inventory=station_metadata)

# %% [markdown]
# ## Visualize Waveforms at Station 'HOLB'

# %%
op = data.select(station='HOLB').plot()

# %%
working = data.copy()

# %%
import obspy

# %%
#working.trim(starttime=obspy.UTCDateTime('2019-12-23T20:56'), endtime=obspy.UTCDateTime('2019-12-23T21:15'))

# %%
#op = working.plot()

# %%
working.filter(type='bandpass', freqmin=3, freqmax=20)
# Out:
# 27 Trace(s) in Stream:
#
# CN.BFSB..HNE | 2019-12-23T20:46:23.560000Z - 2019-12-23T21:11:23.550000Z | 100.0 Hz, 150000 samples
# ...
# (25 other traces)
# ...
# CN.VGZ..HNZ | 2019-12-23T20:46:23.560000Z - 2019-12-23T21:11:23.550000Z | 100.0 Hz, 150000 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]

# %%
op = working.select(station='HOLB').plot()

# %%
# Run Through Sta_list and Cut and Store
for sta in tqdm(sta_list):
    nn_ip_file = '{}.in'.format(sta)
    nn_op_file = '{}.out'.format(sta)
    cha_list = channels[choice]
    
    st_ns = working.select(station=sta,channel=cha_list[0])
    st_ns_fname = os.path.join(event_folder_path,'{}_{}.mseed'.format(sta,cha_list[0]))
    if not st_ns.traces:
        continue
    
    st_ew = working.select(station=sta,channel=cha_list[1])
    st_ew_fname = os.path.join(event_folder_path,'{}_{}.mseed'.format(sta,cha_list[1]))
    if not st_ew.traces:
        continue
    
    st_z = working.select(station=sta,channel=cha_list[2])
    st_z_fname = os.path.join(event_folder_path,'{}_{}.mseed'.format(sta,cha_list[2]))
    if not st_z.traces:
        continue
    
    # Write Streams to Files (writing here to ensure empty stations are ignored outright)
    stream_writer(st_ns,st_ns_fname)
    stream_writer(st_ew,st_ew_fname)
    stream_writer(st_z,st_z_fname)
    
    # InFile String
    in_file_content = '{} {} {}'.format(os.path.relpath(st_ns_fname,'..'),
                                        os.path.relpath(st_ew_fname,'..'),
                                        os.path.relpath(st_z_fname,'..'))
    # Create InFile
    with open(os.path.join(event_folder_path,nn_ip_file),'w') as f:
        f.write(in_file_content)
    command_ip = os.path.relpath(os.path.join(event_folder_path,nn_ip_file),'..')
    
    # Create OutFile
    with open(os.path.join(event_folder_path,nn_op_file),'w') as f:
        f.close()
    command_op = os.path.relpath(os.path.join(event_folder_path,nn_op_file),'..')
    
    print('python gpd_predict.py -V -I {} -O {}'.format(command_ip,command_op))
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# c:\users\aksha\desktop\obspy\obspy\io\mseed\core.py:785: UserWarning: The encoding specified in trace.stats.mseed.encoding does not match the dtype of the data.
# A suitable encoding will be chosen.
#   warnings.warn(msg, UserWarning)
# python gpd_predict.py -V -I data\event_6_2019-12-23T20_56_23_555000Z_acc\HOLB.in -O data\event_6_2019-12-23T20_56_23_555000Z_acc\HOLB.out
# python gpd_predict.py -V -I data\event_6_2019-12-23T20_56_23_555000Z_acc\VGZ.in -O data\event_6_2019-12-23T20_56_23_555000Z_acc\VGZ.out
# python gpd_predict.py -V -I data\event_6_2019-12-23T20_56_23_555000Z_acc\CLRS.in -O data\event_6_2019-12-23T20_56_23_555000Z_acc\CLRS.out
# python gpd_predict.py -V -I data\event_6_2019-12-23T20_56_23_555000Z_acc\NLLB.in -O data\event_6_2019-12-23T20_56_23_555000Z_acc\NLLB.out
# python gpd_predict.py -V -I data\event_6_2019-12-23T20_56_23_555000Z_acc\PACB.in -O data\event_6_2019-12-23T20_56_23_555000Z_acc\PACB.out
# python gpd_predict.py -V -I data\event_6_2019-12-23T20_56_23_555000Z_acc\HOPB.in -O data\event_6_2019-12-23T20_56_23_555000Z_acc\HOPB.out
# python gpd_predict.py -V -I data\event_6_2019-12-23T20_56_23_555000Z_acc\SYMB.in -O data\event_6_2019-12-23T20_56_23_555000Z_acc\SYMB.out
# python gpd_predict.py -V -I data\event_6_2019-12-23T20_56_23_555000Z_acc\SNB.in -O data\event_6_2019-12-23T20_56_23_555000Z_acc\SNB.out
# python gpd_predict.py -V -I data\event_6_2019-12-23T20_56_23_555000Z_acc\BFSB.in -O data\event_6_2019-12-23T20_56_23_555000Z_acc\BFSB.out
