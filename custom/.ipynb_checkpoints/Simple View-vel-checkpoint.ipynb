# %% [markdown]
# ## Load EST_LIB

# %%
from est_lib.util.obspy_util import *
from est_lib.util.obspy_plot import *

# %% [markdown]
# ## Specify Event and Stations of Interest

# %% [markdown]
# ## Retrieve Station Metadata

# %%
station_metadata = inventory_retriever(sta_list=['HOLB'])

# %% [markdown]
# ## Retrieve Waveform Data

# %%
data = stream_reader('264_HOLB-acceleration.mseed')

# %% [markdown]
# ## Visualize EQ Source and Stations

# %%
lat = 50.178
lon = -129.816
op = ray_plot(
    ev_lat=lat,
    ev_lon=lon,
    streams=data,
    inventory=station_metadata)

# %% [markdown]
# ## Visualize Waveforms at Station 'HOLB'

# %%
op = data.select(station='HOLB').plot()

# %%
working = data.copy()

# %%
import obspy

# %%
working.trim(starttime=obspy.UTCDateTime('2019-12-23T20:56'), endtime=obspy.UTCDateTime('2019-12-23T21:15'))
# Out:
# 3 Trace(s) in Stream:
# CN.HOLB..HNE | 2019-12-23T20:56:00.000000Z - 2019-12-23T21:15:00.000000Z | 100.0 Hz, 114001 samples
# CN.HOLB..HNN | 2019-12-23T20:56:00.000000Z - 2019-12-23T21:15:00.000000Z | 100.0 Hz, 114001 samples
# CN.HOLB..HNZ | 2019-12-23T20:56:00.000000Z - 2019-12-23T21:15:00.000000Z | 100.0 Hz, 114001 samples

# %%
op = working.plot()

# %%
working.filter(type='bandpass', freqmin=3, freqmax=20)
# Out:
# 3 Trace(s) in Stream:
# CN.HOLB..HNE | 2019-12-23T20:56:00.000000Z - 2019-12-23T21:15:00.000000Z | 100.0 Hz, 114001 samples
# CN.HOLB..HNN | 2019-12-23T20:56:00.000000Z - 2019-12-23T21:15:00.000000Z | 100.0 Hz, 114001 samples
# CN.HOLB..HNZ | 2019-12-23T20:56:00.000000Z - 2019-12-23T21:15:00.000000Z | 100.0 Hz, 114001 samples

# %%
op = working.plot()

# %%
from obspy.signal.trigger import ar_pick
tr1 = working.select(station='HOLB',channel='HNZ')[0]
tr2 = working.select(station='HOLB',channel='HNN')[0]
tr3 = working.select(station='HOLB',channel='HNE')[0]
df = 100

# %%
p_pick, s_pick = ar_pick(tr1.data, tr2.data, tr3.data, df,
                         1.0, 20.0, 1.0, 0.1, 4.0, 1.0, 2, 8, 0.1, 0.2)

# %%
p_time = obspy.UTCDateTime(tr1.stats.starttime)+p_pick

# %%
s_time = obspy.UTCDateTime(tr1.stats.starttime)+s_pick

# %%
a = np.zeros(len(tr1),dtype=float)
p = a.copy()
s = a.copy()

p[int(p_pick*df-250):int(p_pick*df-249)]=max(tr1)
s[int(s_pick*df-250):int(s_pick*df-249)]=max(tr2)

plt.figure(figsize=(15, 20))
plt.subplot(3,1,1)
plt.title('Phase Onset Estimated Using Expert Algorithm')
plt.plot(tr1.data,label='Channel = EW')
plt.plot(p,'b',label='p-wave onset, time = {}'.format(p_time))
plt.plot(s,'r',label='s-wave onset, time = {}'.format(s_time))
plt.xlim([0,30000])
plt.grid()
plt.axis()
plt.legend()
plt.subplot(3,1,2)
plt.plot(tr2.data,label="Channel = NS")
plt.plot(p,'b',label='p-wave onset, time = {}'.format(p_time))
plt.plot(s,'r',label='s-wave onset, time = {}'.format(s_time))
plt.xlim([0,30000])
plt.grid()
plt.axis()
plt.legend()
plt.subplot(3,1,3)
plt.plot(tr3.data,label="Channel = Z")
plt.plot(p,'b',label='p-wave onset, time = {}'.format(p_time))
plt.plot(s,'r',label='s-wave onset, time = {}'.format(s_time))
plt.xlim([0,30000])
plt.grid()
plt.axis()
plt.legend()
plt.show()

# %%
# Cut and Store - Velocity
st_ew = working.select(channel="HNE")
st_ns = working.select(channel="HNN")
st_z = working.select(channel="HNZ")

# %%
stream_writer(st_ew,'HOLB_HNE.mseed')
stream_writer(st_ew,'HOLB_HNN.mseed')
stream_writer(st_ew,'HOLB_HNZ.mseed')
# Out:
# c:\users\aksha\desktop\obspy\obspy\io\mseed\core.py:785: UserWarning: The encoding specified in trace.stats.mseed.encoding does not match the dtype of the data.
# A suitable encoding will be chosen.
#   warnings.warn(msg, UserWarning)
# 'C:\\Users\\aksha\\Desktop\\generalized-phase-detection\\custom\\HOLB_HNZ.mseed'
